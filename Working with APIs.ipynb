# %%
import requests
import pandas as pd
import json
import getpass
rapidAPIkey = getpass.getpass()
# Out:
# ········

# %% [markdown]
# # 1

# %%
res = requests.get('https://inshorts.deta.dev/news?category=startup')

# %%
data = res.json()
data
# Out:
# {'category': 'startup',
#  'data': [{'author': 'Pragya Swastik',
#    'content': 'Elon Musk has officially broken the world record for the largest loss of personal fortune in history, the Guinness World Records said. "He lost approximately $182 billion since November 2021, as estimated by Forbes, although other sources suggest it could actually be closer to $200 billion," Guinness added. Musk\'s wealth largely dropped due to the poor performance of Tesla\'s stock.',
#    'date': '09 Jan 2023,Monday',
#    'id': 'a75cd58d7ca1451d975b79aa5d36350f',
#    'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2023/01_jan/9_mon/img_1673274981577_239.jpg?',
#    'readMoreUrl': 'https://www.guinnessworldrecords.com/amp/news/2023/1/elon-musk-suffers-worst-loss-of-fortune-in-history-amid-market-madness-731988?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ',
#    'time': '08:47 pm',
# ...

# %%
from pandas import json_normalize
flattened_data = json_normalize(data)
flattened_data
print(flattened_data['data'][0])
# Out:
# [{'author': 'Pragya Swastik', 'content': 'Elon Musk has officially broken the world record for the largest loss of personal fortune in history, the Guinness World Records said. "He lost approximately $182 billion since November 2021, as estimated by Forbes, although other sources suggest it could actually be closer to $200 billion," Guinness added. Musk\'s wealth largely dropped due to the poor performance of Tesla\'s stock.', 'date': '09 Jan 2023,Monday', 'id': 'a75cd58d7ca1451d975b79aa5d36350f', 'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2023/01_jan/9_mon/img_1673274981577_239.jpg?', 'readMoreUrl': 'https://www.guinnessworldrecords.com/amp/news/2023/1/elon-musk-suffers-worst-loss-of-fortune-in-history-amid-market-madness-731988?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ', 'time': '08:47 pm', 'title': 'Musk enters Guinness World Records for the largest loss of personal fortune', 'url': 'https://www.inshorts.com/en/news/musk-ente
# ...

# %%
import random

def random_startup(data):
    print(data['data'][random.randint(0, len(data)-1)])

# %%
random_startup(flattened_data)
# Out:
# [{'author': 'Pragya Swastik', 'content': 'Elon Musk has officially broken the world record for the largest loss of personal fortune in history, the Guinness World Records said. "He lost approximately $182 billion since November 2021, as estimated by Forbes, although other sources suggest it could actually be closer to $200 billion," Guinness added. Musk\'s wealth largely dropped due to the poor performance of Tesla\'s stock.', 'date': '09 Jan 2023,Monday', 'id': 'a75cd58d7ca1451d975b79aa5d36350f', 'imageUrl': 'https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2023/01_jan/9_mon/img_1673274981577_239.jpg?', 'readMoreUrl': 'https://www.guinnessworldrecords.com/amp/news/2023/1/elon-musk-suffers-worst-loss-of-fortune-in-history-amid-market-madness-731988?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts ', 'time': '08:47 pm', 'title': 'Musk enters Guinness World Records for the largest loss of personal fortune', 'url': 'https://www.inshorts.com/en/news/musk-ente
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#    category                                               data  success
# 0   startup  {'author': 'Pragya Swastik', 'content': 'Elon ...     True
# 1   startup  {'author': 'Hiral Goyal', 'content': 'The firs...     True
# 2   startup  {'author': 'Pragya Swastik', 'content': 'The D...     True
# 3   startup  {'author': 'Hiral Goyal', 'content': 'Ashneer ...     True
# 4   startup  {'author': 'Ananya Goyal', 'content': 'Venture...     True
# 5   startup  {'author': 'Ananya Goyal', 'content': 'Busines...     True
# 6   startup  {'author': 'Aishwarya Awasthi', 'content': 'Th...     True
# 7   startup  {'author': 'Aishwarya Awasthi', 'content': 'Ja...     True
# 8   startup  {'author': 'Ananya Goyal', 'content': 'Byju's ...     True
# 9   startup  {'author': 'Aishwarya Awasthi', 'content': 'Ze...     True
# 10  startup  {'author': 'Purnima Rajput', 'content': 'Early...     True
# 11  startup  {'author': 'Purnima Rajput', 'content': 'Edtec...     True
# ...

# %%
from pandas.io.json import json_normalize
flattened_data = json_normalize(data)
flattened_data
print(flattened_data['success'][0])
# Out:
# True
# /var/folders/q5/ywjsx89514x2b_9dvdlcfngw0000gn/T/ipykernel_2848/452676777.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattened_data = json_normalize(data)

# %% [markdown]
# # 2

# %%
res2 = requests.get('https://whiskyhunter.net/api/auctions_data')

# %%
res2
# Out:
# <Response [200]>

# %%
import requests
import pandas as pd
import json
import getpass
rapidAPIkey = getpass.getpass()
# Out:
# ········

# %%
data2 = res2.json()
data2
# Out:
# [{'dt': '2022-12-01',
#   'winning_bid_max': 14234.4,
#   'winning_bid_min': 2.6,
#   'winning_bid_mean': 184.13,
#   'auction_trading_volume': 1087289.9,
#   'auction_lots_count': 5905,
#   'all_auctions_lots_count': 38309,
#   'auction_name': 'Catawiki Whisky Auction',
#   'auction_slug': 'catawiki'},
#  {'dt': '2022-12-01',
#   'winning_bid_max': 4402.3,
#   'winning_bid_min': 7.9,
#   'winning_bid_mean': 293.98,
#   'auction_trading_volume': 37335.4,
#   'auction_lots_count': 127,
#   'all_auctions_lots_count': 38309,
#   'auction_name': 'Celtic Whiskey Auction',
#   'auction_slug': 'celtic-whiskey-auction'},
#  {'dt': '2022-12-01',
#   'winning_bid_max': 4257.1,
#   'winning_bid_min': 17.2,
#   'winning_bid_mean': 289.55,
#   'auction_trading_volume': 50381.0,
#   'auction_lots_count': 174,
#   'all_auctions_lots_count': 38309,
#   'auction_name': 'European Whisky Auctions',
#   'auction_slug': 'european-whisky-auctions'},
#  {'dt': '2022-12-01',
#   'winning_bid_max': 3300.0,
# ...

# %%
df = pd.DataFrame(data2)
df
# Out:
#               dt  winning_bid_max  winning_bid_min  winning_bid_mean  \
# 0     2022-12-01          14234.4              2.6            184.13
# 1     2022-12-01           4402.3              7.9            293.98
# 2     2022-12-01           4257.1             17.2            289.55
# 3     2022-12-01           3300.0              0.0            124.68
# 4     2022-12-01           8892.6              4.4            269.06
# ...          ...              ...              ...               ...
# 1524  2006-03-01            830.0              1.0             47.07
# 1525  2006-02-01           1194.0              1.0             44.11
# 1526  2006-01-01            981.0              1.0             58.01
# 1527  2005-12-01           1247.0              1.0             50.74
# 1528  2005-11-01           1293.0              1.0             45.37
#
#       auction_trading_volume  auction_lots_count  all_auctions_lots_count  \
# ...

# %%
from pandas.io.json import json_normalize
flattened_data = json_normalize(data2)
flattened_data
print(flattened_data['auction_name'][1])
# Out:
# Celtic Whiskey Auction
# /var/folders/q5/ywjsx89514x2b_9dvdlcfngw0000gn/T/ipykernel_2848/1475345385.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattened_data = json_normalize(data2)

# %% [markdown]
# # 3

# %%
res3 = requests.get('https://www.fruityvice.com/api/fruit/all')

# %%
res3
# Out:
# <Response [200]>

# %%
data3 = res3.json()
data3
# Out:
# [{'genus': 'Malus',
#   'name': 'Apple',
#   'id': 6,
#   'family': 'Rosaceae',
#   'order': 'Rosales',
#   'nutritions': {'carbohydrates': 11.4,
#    'protein': 0.3,
#    'fat': 0.4,
#    'calories': 52,
#    'sugar': 10.3}},
#  {'genus': 'Prunus',
#   'name': 'Apricot',
#   'id': 35,
#   'family': 'Rosaceae',
#   'order': 'Rosales',
#   'nutritions': {'carbohydrates': 3.9,
#    'protein': 0.5,
#    'fat': 0.1,
#    'calories': 15,
#    'sugar': 3.2}},
#  {'genus': 'Persea',
#   'name': 'Avocado',
#   'id': 84,
#   'family': 'Lauraceae',
#   'order': 'Laurales',
#   'nutritions': {'carbohydrates': 8.53,
#    'protein': 2,
#    'fat': 14.66,
#    'calories': 160,
#    'sugar': 0.66}},
#  {'genus': 'Musa',
#   'name': 'Banana',
#   'id': 1,
#   'family': 'Musaceae',
#   'order': 'Zingiberales',
#   'nutritions': {'carbohydrates': 22,
#    'protein': 1,
#    'fat': 0.2,
#    'calories': 96,
#    'sugar': 17.2}},
#  {'genus': 'Rubus',
#   'name': 'Blackberry',
#   'id': 64,
# ...

# %%
# Out:
# [{'genus': 'Malus',
#   'name': 'Apple',
#   'id': 6,
#   'family': 'Rosaceae',
#   'order': 'Rosales',
#   'nutritions': {'carbohydrates': 11.4,
#    'protein': 0.3,
#    'fat': 0.4,
#    'calories': 52,
#    'sugar': 10.3}},
#  {'genus': 'Prunus',
#   'name': 'Apricot',
#   'id': 35,
#   'family': 'Rosaceae',
#   'order': 'Rosales',
#   'nutritions': {'carbohydrates': 3.9,
#    'protein': 0.5,
#    'fat': 0.1,
#    'calories': 15,
#    'sugar': 3.2}},
#  {'genus': 'Persea',
#   'name': 'Avocado',
#   'id': 84,
#   'family': 'Lauraceae',
#   'order': 'Laurales',
#   'nutritions': {'carbohydrates': 8.53,
#    'protein': 2,
#    'fat': 14.66,
#    'calories': 160,
#    'sugar': 0.66}},
#  {'genus': 'Musa',
#   'name': 'Banana',
#   'id': 1,
#   'family': 'Musaceae',
#   'order': 'Zingiberales',
#   'nutritions': {'carbohydrates': 22,
#    'protein': 1,
#    'fat': 0.2,
#    'calories': 96,
#    'sugar': 17.2}},
#  {'genus': 'Rubus',
#   'name': 'Blackberry',
#   'id': 64,
# ...

# %%
data3 = res3.json()
data3
# Out:
# [{'genus': 'Malus',
#   'name': 'Apple',
#   'id': 6,
#   'family': 'Rosaceae',
#   'order': 'Rosales',
#   'nutritions': {'carbohydrates': 11.4,
#    'protein': 0.3,
#    'fat': 0.4,
#    'calories': 52,
#    'sugar': 10.3}},
#  {'genus': 'Prunus',
#   'name': 'Apricot',
#   'id': 35,
#   'family': 'Rosaceae',
#   'order': 'Rosales',
#   'nutritions': {'carbohydrates': 3.9,
#    'protein': 0.5,
#    'fat': 0.1,
#    'calories': 15,
#    'sugar': 3.2}},
#  {'genus': 'Persea',
#   'name': 'Avocado',
#   'id': 84,
#   'family': 'Lauraceae',
#   'order': 'Laurales',
#   'nutritions': {'carbohydrates': 8.53,
#    'protein': 2,
#    'fat': 14.66,
#    'calories': 160,
#    'sugar': 0.66}},
#  {'genus': 'Musa',
#   'name': 'Banana',
#   'id': 1,
#   'family': 'Musaceae',
#   'order': 'Zingiberales',
#   'nutritions': {'carbohydrates': 22,
#    'protein': 1,
#    'fat': 0.2,
#    'calories': 96,
#    'sugar': 17.2}},
#  {'genus': 'Rubus',
#   'name': 'Blackberry',
#   'id': 64,
# ...

# %%
df = pd.DataFrame(data3)
df
# Out:
#            genus          name  id           family             order  \
# 0          Malus         Apple   6         Rosaceae           Rosales
# 1         Prunus       Apricot  35         Rosaceae           Rosales
# 2         Persea       Avocado  84        Lauraceae          Laurales
# 3           Musa        Banana   1         Musaceae      Zingiberales
# 4          Rubus    Blackberry  64         Rosaceae           Rosales
# 5       Fragaria     Blueberry  33         Rosaceae           Rosales
# 6         Prunus        Cherry   9         Rosaceae           Rosales
# 7      Theobroma     Chocolate  88        Malvaceae          Malvales
# 8      Vaccinium     Cranberry  87        Ericaceae          Ericales
# 9   Selenicereus   Dragonfruit  80        Cactaceae    Caryophyllales
# 10         Durio        Durian  60        Malvaceae          Malvales
# 11    Sellowiana        Feijoa  76        Myrtaceae        Myrtoideae
# ...

# %%
from pandas.io.json import json_normalize
flattened_data = json_normalize(data3)
flattened_data
print(flattened_data['id'][1])
# Out:
# 35
# /var/folders/q5/ywjsx89514x2b_9dvdlcfngw0000gn/T/ipykernel_2848/3352826120.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattened_data = json_normalize(data3)
